# %%
import math

# %%
def tree_ratio(n, k): 
    return ((1/2)**(n))*math.factorial(n) / (math.factorial(k)*math.factorial(n-k))

# %%
n = 100

data = [tree_ratio(n, i) for i in range(n)]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(data)
